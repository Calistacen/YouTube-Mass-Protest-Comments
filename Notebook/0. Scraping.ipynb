# %% [markdown]
# ## **A Comparative Study of LDA and BERT-Based Topic Modeling on Indonesian YouTube Protest Discourse**
# #### an research for analyzing the performance of LDA and BERTopic on topic modelling for youtube comments for Indonesian DPR Dissolution Protest
#
# ##### *Comment Scrapping*

# %%
import googleapiclient.discovery
import pandas as pd

# %%
# Setting the scraper function

api_services_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyBCRRfakuvhB49FDtBpX8ABzSPTHmtD4jI" 

youtube = googleapiclient.discovery.build(
    api_services_name, api_version, developerKey=DEVELOPER_KEY
)

def getcomments(video_id, limit=1500):
    comments = []
    next_page_token = None

    while len(comments) < limit:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token
        )

        response = request.execute()

        for item in response["items"]:
            if len(comments) >= limit:
                break  # stop exactly at limit

            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append([
                snippet["authorDisplayName"],
                snippet["likeCount"],
                snippet["textOriginal"],
                snippet["videoId"],
                item["snippet"]["isPublic"]
            ])

        # stop if no more pages
        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    df_yt = pd.DataFrame(
        comments,
        columns=["Account", "likeCount", "Comments", "Video_id", "public"]
    )

    return df_yt

# %%
# Start by collecting comments from one video

df = getcomments("3JiWoX-g4Yo")
df

# %%
#turn df into dataframe, and append the rest of the comment from other videos

df = pd.DataFrame()

for i in ["QVCMPYvf5U0", "jcavf1xEFJE", "CMJswJTNqqU", "zMjUozwpkVA", "fjLaHU_lRfQ", 
          "3kII4AWZ1kA", "UGv1ruOfi0M", "kOS3ycDB82g", "Gim--luwL5I"]: 
    df2 = getcomments(i)
    df = pd.concat([df, df2])
    df

# %%
# Recheck the function validation to ensure balance

df['Video_id'].value_counts()

# %%
# Check the dataframe

print(df)

# %%
#Save dataframe as a csv file

df.to_csv("ytc_raw.csv")
